# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloCavanzo/MetodosI_AntonioMorillo_PabloCavanzo/blob/main/Tarea%20m%C3%ADnimos%20cuadrados/9.4.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from google.colab import drive
import scipy.optimize as spo
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/Colab/MetodosI_AntonioMorillo_PabloCavanzo')
# !ls
# Out:
# 9.4.3.ipynb  9.4.4.ipynb  MinimosCuadratico.txt  MinimosLineal.txt  Sesión.ipynb

# %%
fileL = '/content/drive/MyDrive/Colab/MetodosI_AntonioMorillo_PabloCavanzo/MinimosLineal.txt'
fileC = '/content/drive/MyDrive/Colab/MetodosI_AntonioMorillo_PabloCavanzo/MinimosCuadratico.txt'

# %%
def fL(x,a0,a1):
  return a0+a1*x
def fC(x,a0,a1,a2):
  return a0+a1*x+a2*x**2

# %%
dataL = pd.read_csv(fileL, sep=' ')
dataL.columns = ['x', 'y']
xL = np.array(dataL['x'])
yL = np.array(dataL['y'])
dataC = pd.read_csv(fileC, sep=' ')
dataC.columns = ['x', 'y']
xC = np.array(dataC['x'])
yC = np.array(dataC['y'])

# %%
fig, ax = plt.subplots(1,2, figsize=(10,5))
curvaL = spo.curve_fit(fL,xL,yL)
ax[0].plot(xL,yL,'o')
ax[0].plot(xL,fL(xL,*curvaL[0]))
ax[0].grid()
ax[0].set_title('Ajuste Lineal')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
curvaC = spo.curve_fit(fC,xC,yC)
ax[1].plot(xC,yC,'o')
ax[1].plot(xC,fC(xC,*curvaC[0]))
ax[1].grid()
ax[1].set_title('Ajuste Cuadratico')
ax[1].set_xlabel('x')
ax[1].set_ylabel('y')
plt.show()
print('Lineal:')
print('f(x) = {} + {}x'.format(round(curvaL[0][0],4),round(curvaL[0][1],4)))
print('\nCuadratico:')
print('f(x) = {} + {}x + {}x^2'.format(round(curvaC[0][0],4),round(curvaC[0][1],4),round(curvaC[0][2],4)))
# Out:
# Lineal:
# f(x) = -5.2073 + 2.1307x
#
# Cuadratico:
# f(x) = 1.2213 + 6.0908x + 2.9566x^2

# %% [markdown]
# Comparación:
#
# Ajuste lineal obtenida con mínimos cuadrados: f(x) = -5.2073 + 2.1307x
#
# Ajuste lineal obtenida con el método curve_fit: f(x) = -5.1292 + 2.125x
#
# Ajuste cuadrático obtenido con mínimos cuadrados: f(x) = 1.2213 + 6.0908x + 2.9566x^2
#
# Ajuste Cuadrático obtenido con mínimos cuadrados: f(x) = 1.2213 + 6.0908x + 2.9566x^2
#
# Se puede observar que con el método de mínimos cuadrados se obtuvieron regresiones muy parecidas a las que obtenidas con con el método curve_fit.
