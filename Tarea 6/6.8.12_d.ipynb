# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloCavanzo/MetodosI_AntonioMorillo_PabloCavanzo/blob/main/Tarea%206/6.8.12_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,50,10000)

# %%
# sea y = S(N, x)/(Kb*N)
y = -1*(x*np.log(x) + (1 - x)*np.log(1 - x))
# Out:
# <ipython-input-12-58977966f5b6>:2: RuntimeWarning: divide by zero encountered in log
#   y = -1*(x*np.log(x) + (1 - x)*np.log(1 - x))
# <ipython-input-12-58977966f5b6>:2: RuntimeWarning: invalid value encountered in multiply
#   y = -1*(x*np.log(x) + (1 - x)*np.log(1 - x))
# <ipython-input-12-58977966f5b6>:2: RuntimeWarning: invalid value encountered in log
#   y = -1*(x*np.log(x) + (1 - x)*np.log(1 - x))

# %%
plt.plot(x,y)
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.title('$S(N, x)/(Kb*N) vs. (x = n_1/N)$')
plt.show()
