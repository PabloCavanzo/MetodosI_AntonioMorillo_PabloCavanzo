# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloCavanzo/MetodosI_AntonioMorillo_PabloCavanzo/blob/main/Tarea%206/6.8_12_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0.000001,0.99999,1000)

# %%
# sea y = S(N, x)/(Kb*N)
y = -1*(x*np.log(x) + (1 - x)*np.log(1 - x))

# %%
plt.plot(x,y)
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.title('$S(N, x)/(k_B*N) vs. (x = n_1/N)$')
plt.show()
